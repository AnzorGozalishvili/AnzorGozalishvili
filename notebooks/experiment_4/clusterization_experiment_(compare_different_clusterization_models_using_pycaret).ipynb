# %% [markdown]
# <a href="https://colab.research.google.com/github/AnzorGozalishvili/AnzorGozalishvili/blob/main/notebooks/experiment_4/clusterization_experiment_(compare_different_clusterization_models_using_pycaret).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eye color clustering
#
# ## Introduction
#
# The objective of this analysis is identifying a suitable clustering for eye colors. We will use a dataset of eye images where for each eye we have both the average color of the collarette (eye internal part close to the pupil) and iris, both expressed in the CIELab system. We will perform four different clusterings, by considering:
#
# - either the color of the whole eye (average between collarette and iris) or only the iris color;
# - either the CIELab colors in their original values or their scaled (zero mean, unary variance) version.

# %% [markdown]
# # Set up

# %%
# !mkdir --parent notebooks/experiment4/
# !pip install pandas==1.2.1 \
# xlrd==1.2.0 \
# numpy==1.19.5 \
# opencv-python==4.5.2.54 \
# plotly==4.14.3 \
# colormath==3.0.0 \
# scikit-learn==1.0.1 \

# !pip install scikit-learn-extra
# !pip install -U pycaret
# !pip install --upgrade openpyxl

# %%
import sys
import os

import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import cv2
import plotly.io as pio

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import adjusted_rand_score

from colormath.color_objects import sRGBColor,LabColor
from colormath.color_conversions import convert_color

if "notebooks/experiment4" not in os.getcwd():
  os.chdir('notebooks/experiment4/')

# %%
# %config Completer.use_jedi = False
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Config option `use_jedi` not recognized by `IPCompleter`.
#   """Entry point for launching an IPython kernel.

# %%
FIGURES_DIR = './Figures/'
CLUSTERS_DIR = "./Clusters/"
DATASETS_DIR = "./Datasets/"
METRICS_DIR = "./Metrics/"

# %%
if not os.path.exists(FIGURES_DIR):
    os.mkdir(FIGURES_DIR)

if not os.path.exists(CLUSTERS_DIR):
  os.mkdir(CLUSTERS_DIR)

if not os.path.exists(DATASETS_DIR):
  os.mkdir(DATASETS_DIR)

if not os.path.exists(METRICS_DIR):
  os.mkdir(METRICS_DIR)

# %%
NUM_CLUSTERS = 4

# %% [markdown]
# # Data Preparation
#
# Let’s now load and prepare our data. We will create two datasets, one considering the whole eye (collarette + iris), the other only the iris

# %% [markdown]
# ## Helper Functions

# %%
def lab_to_hex(l, a, b):

    lab = LabColor(lab_l=l, lab_a=a, lab_b=b, observer='2', illuminant='d65')
    rgb = convert_color(color=lab, target_cs=sRGBColor)

    return rgb.get_rgb_hex()

# %%
def show_lab_scatter_3d(dataframe):
    trace=dict(type='scatter3d',
           x=dataframe.l.values,
           y=dataframe.a.values,
           z=dataframe.b.values,
           mode='markers',
           marker=dict(color=dataframe.hex_color.values, size=7),
          )
    
    pio.show(trace)
    return trace

# %%
def show_lab_scatter_3d_shapes(dataframe, labels):
    cluster_ids = dataframe.Cluster.value_counts().index.tolist()
    shapes = ['circle', 'square',  'diamond', 'cross']
    shapes_map = {}
    for idx, cluster_id in enumerate(cluster_ids):
        # set shape value in order but if no more shape is available then the last one to each.
        shapes_map[cluster_id] = shapes[idx if idx < len(shapes) else -1]
    
    trace=dict(type='scatter3d',
           x=dataframe.l.values,
           y=dataframe.a.values,
           z=dataframe.b.values,
           text=labels.Colore_IRISPLEX.values,
           mode='markers',
           marker=dict(
               color=dataframe.hex_color.values,
               size=7,
               symbol=dataframe.Cluster.apply(lambda x: shapes_map[x])),
          )
    
    pio.show(trace)
    return trace

# %% [markdown]
# ## Outer Iris

# %%
dataset_outer_iris = pd.read_excel('../../dataset/IrisPlex_20_01_2022_filtered.xlsx')[['ID', 'Outer.Iris.L', 'Outer.Iris.a', 'Outer.Iris.b']]

# %%
dataset_outer_iris.set_index('ID', inplace=True)

# %%
dataset_outer_iris.columns = ['l', 'a', 'b']

# %%
dataset_outer_iris['hex_color'] = dataset_outer_iris.apply(lambda x: lab_to_hex(*x.values), axis=1)

# %%
dataset_outer_iris.head(3)
# Out:
#                 l         a          b hex_color
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18
# FDP002  22.662753  2.493072  17.055058   #42341d
# FDP003  44.268597 -5.288547   8.743492   #666b5a

# %%
pio.write_html(fig=show_lab_scatter_3d(dataset_outer_iris), file=FIGURES_DIR + "dataset_outer_iris.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="2d0593ca-4d3b-4d2b-a25c-eee805ba3468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d0593ca-4d3b-4d2b-a25c-eee805ba3468")) {                    Plotly.newPlot(                        "2d0593ca-4d3b-4d2b-a25c-eee805ba3468",                        [{"marker": {"color": ["#332a18", "#42341d", "#666b5a", "#706141", "#497690", "#363335", "#4c4e35", "#587d87", "#536964", "#819587", "#62605b", "#4b6c6d", "#191d26", "#626b49", "#262426", "#503f2f", "#35647f", "#4a788f", "#31251e", "#171414", "#4f645a", "#302824", "#5a858e", "#4d443a", "#4b3f1f", "#4b463d", "#25211f", "#201f23", "#38443f", "#3d6379", "#3b3420", "#3b3432", "#5a645b", "#413834", "#3f3836", "#45717f", "#4b452b", "#39302c", "#404431", "#4f3f35", "#372b1c", "#676248", "#3e3c38", "#5e5134", "#544430", "#4c413d", "#30241e", "#3d3530", "#2c2c2e", "#4d3c2a", "#5a797d", "#2c2422", "#594b3c", "#413731", "#3e2f29", "#272c34", "#465a59", "#474a35", "#5e5444", "#4d382e", "#627174", "#302620", "#554a3d", "#393934", "#3d3736", "#30251d", "#444a45", "#2b2e38", "#312c2b", "#454c3b", "#373324", "#575958", "#3c6373", "#595545", "#51452a", "#2b271d", "#3f3126", "#39322f", "#343221", "#6a7d6f", "#404e4e", "#1f1f23", "#221c1b", "#654c23", "#3c332d", "#67553b", "#2f2b2a", "#5c6154", "#372d28", "#372d2a", "#524235", "#443b33", "#707057", "#60634a", "#513d31", "#322722", "#59584a", "#5b5447", "#454f40", "#40322d", "#3f3939", "#4d3c2f", "#63573a", "#3e514b", "#483929", "#58452f", "#4e7585", "#4a8099", "#4e3d2a", "#3f3d2e", "#2e2b2c", "#5b4a40", "#332e31", "#322b2c", "#5e524f", "#4e5952", "#6a7c69", "#4b4028", "#282527", "#2d2627", "#685638", "#464034", "#5b6e70", "#352619", "#564b47", "#5b8594", "#65513c", "#6c5b37", "#3a3c46", "#2e2623", "#39373d", "#393436", "#5a4934", "#3b2f28", "#595047", "#40352a", "#4f412f", "#638892", "#4b3928", "#464330", "#5a7f8c", "#46422c", "#534a41", "#424238", "#58655a", "#595340", "#221d1c", "#44362a", "#41779a", "#453a37", "#535247", "#5a4034", "#5e6456", "#615d45", "#36363c", "#3e3c42", "#4f423c", "#332b29", "#433327", "#4b392f", "#304e56", "#527e8c", "#6c7b68", "#443125", "#5c635b", "#6f785e", "#242124", "#514e52", "#222023", "#425b5b", "#738f97", "#524a36", "#685135", "#3e3a27", "#493a1d", "#1b1410", "#382923", "#2a2016", "#362a22", "#49615f", "#2d6a91", "#373133", "#382c27", "#4e462e", "#79643f", "#5d4833", "#38343a", "#334c50", "#312829", "#4f3d2b", "#37302f", "#4c3d25", "#261b10", "#55442b", "#4d4629", "#626342", "#534e44", "#191817", "#53463f", "#453a24", "#372a24", "#403226", "#554440", "#39322d", "#675a34", "#3e341b", "#59482e", "#342921", "#453e28", "#2a2322", "#393022", "#463d22", "#5c4627", "#6b796d", "#504527", "#524623", "#473928", "#412f28", "#342820", "#443936", "#4a3d39", "#524326", "#637973", "#477987", "#60563b", "#4c4138", "#3f332f", "#56412c", "#4e413e", "#47341d", "#28211e", "#645635", "#5d5242", "#3c3231", "#2e251d", "#575033", "#52361f", "#5e3d2a"], "size": 7}, "mode": "markers", "type": "scatter3d", "x": [17.67112935, 22.66275264, 44.26859727, 41.82944889, 47.37800952, 21.68078646, 32.35560359, 50.14762003, 42.46833821, 59.87950903, 40.82894529, 43.09709172, 10.62653542, 43.74760187, 14.62615923, 28.18424071, 40.1782167, 48.18591356, 16.0275987, 6.64359889, 40.34722976, 16.99756866, 52.80946255, 29.53084336, 27.32650055, 29.87821484, 13.17434344, 11.92366279, 27.57516631, 40.13188977, 21.84676121, 22.34226914, 41.41126051, 24.44238376, 24.33507309, 44.97064502, 29.24683393, 20.73361763, 27.94225717, 28.01297433, 18.64877498, 41.24481639, 25.2428781, 35.11317782, 29.86661715, 28.46227713, 15.46618901, 22.77769171, 18.00471846, 26.80520552, 48.65154053, 15.08689061, 32.89713133, 23.77418006, 20.88474512, 17.7482392, 36.48899366, 30.63280991, 36.1 ...

# %% [markdown]
# ### Get Labels

# %%
labels = dataset_outer_iris.merge(
    pd.read_excel('../../dataset/IrisPlex_20_01_2022_filtered.xlsx', index_col=0)[['Colore_IRISPLEX']],
    how='inner',
    left_index=True,
    right_index=True,
)[['Colore_IRISPLEX']]

# %%
labels.shape
# Out:
# (238, 1)

# %% [markdown]
# # Clustering (outer iris)

# %% [markdown]
# Run pycaret experiments using different models and on 2 different datasets that we got here

# %%
from pycaret.clustering import *
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
exp_003 = setup(
    data=dataset_outer_iris,
    preprocess=True,
    ignore_features=['hex_color'],
    
    # normalize
    normalize=False,
    normalize_method='zscore',
    
    # transform
    transformation=False,
    transformation_method='yeo-johnson',
    
    # pca
    pca=False,
    pca_method='linear',
    
    
    silent=True,
    n_jobs=-1,
    
    # set experiment seed
    session_id=123
)
# Out:
#                                Description                 Value
# 0                               session_id                   123
# 1                            Original Data              (238, 4)
# 2                           Missing Values                 False
# 3                         Numeric Features                     3
# 4                     Categorical Features                     0
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data              (238, 3)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  cluster-default-name
# 13                                     USI                  d1b8
# 14                         Imputation Type                simple
# 15          Iterative Imputation Iteration                  None
# 16                         Numeric Imputer                  mean
# 17      Iterative Imputation Numeric Model                  None
# 18                     Categorical Imputer                  mode
# 19  Iterative Imputation Categorical Model                  None
# 20           Unknown Categoricals Handling        least_frequent
# 21                               Normalize                 False
# 22                        Normalize Method                  None
# 23                          Transformation                 False
# 24                   Transformation Method                  None
# 25                                     PCA                 False
# 26                              PCA Method                  None
# 27                          PCA Components                  None
# 28                     Ignore Low Variance                 False
# 29                     Combine Rare Levels                 False
# 30                    Rare Level Threshold                  None
# 31                         Numeric Binning                 False
# 32                         Remove Outliers                 False
# 33                      Outliers Threshold                  None
# 34                Remove Multicollinearity                 False
# 35             Multicollinearity Threshold                  None
# 36             Remove Perfect Collinearity                 False
# 37                              Clustering                 False
# 38                    Clustering Iteration                  None
# 39                     Polynomial Features                 False
# 40                       Polynomial Degree                  None
# 41                    Trignometry Features                 False
# 42                    Polynomial Threshold                  None
# 43                          Group Features                 False
# 44                       Feature Selection                 False
# 45                Feature Selection Method               classic
# 46            Features Selection Threshold                  None
# 47                     Feature Interaction                 False
# 48                           Feature Ratio                 False
# 49                   Interaction Threshold                  None

# %% [markdown]
# show all outputs from cell

# %%
def try_model(model_name, **kwargs):
    # create model
    model = create_model(model_name, **kwargs)
    # show model object
    print(model)
    # store model results
    results = assign_model(model)
    print(results.head(2))
    # evaluate model with interactive plot
    evaluate_model(model)
    
    return model, results

# %%
models_003 = {}
results_003 = {}

MODEL_NAMES = ["kmeans", "ap", "meanshift", "sc", "hclust", "dbscan", "optics", "birch", "kmodes"]

# %%
models_003["kmeans"], results_003["kmeans"] = try_model("kmeans",  **{"num_clusters":4})
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.4066           226.4846  ...           0             0
#
# [1 rows x 6 columns]
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=-1, precompute_distances='deprecated',
#        random_state=123, tol=0.0001, verbose=0)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 2
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["ap"], results_003["ap"] = try_model("ap")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0       0.309           173.6177  ...           0             0
#
# [1 rows x 6 columns]
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#                     damping=0.5, max_iter=200, preference=None,
#                     random_state='warn', verbose=False)
#                 l         a          b hex_color     Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 16
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 14
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["meanshift"], results_003["meanshift"] = try_model("meanshift")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.4891           193.0746  ...           0             0
#
# [1 rows x 6 columns]
# MeanShift(bandwidth=None, bin_seeding=False, cluster_all=True, max_iter=300,
#           min_bin_freq=1, n_jobs=-1, seeds=None)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["sc"], results_003["sc"] = try_model("sc")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.3044             7.0123  ...           0             0
#
# [1 rows x 6 columns]
# SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3,
#                    eigen_solver=None, eigen_tol=0.0, gamma=1.0,
#                    kernel_params=None, n_clusters=4, n_components=None,
#                    n_init=10, n_jobs=-1, n_neighbors=10, random_state=123)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["hclust"], results_003["hclust"] = try_model("hclust")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.3511           186.9224  ...           0             0
#
# [1 rows x 6 columns]
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=4)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["dbscan"], results_003["dbscan"] = try_model("dbscan")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0           0                  0  ...           0             0
#
# [1 rows x 6 columns]
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=-1, p=None)
#                 l         a          b hex_color     Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster -1
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster -1
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["optics"], results_003["optics"] = try_model("optics")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0     -0.2278            13.0414  ...           0             0
#
# [1 rows x 6 columns]
# OPTICS(algorithm='auto', cluster_method='xi', eps=None, leaf_size=30,
#        max_eps=inf, metric='minkowski', metric_params=None,
#        min_cluster_size=None, min_samples=5, n_jobs=-1, p=2,
#        predecessor_correction=True, xi=0.05)
#                 l         a          b hex_color     Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster -1
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster -1
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["birch"], results_003["birch"] = try_model("birch")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0       0.389           204.0435  ...           0             0
#
# [1 rows x 6 columns]
# Birch(branching_factor=50, compute_labels=True, copy=True, n_clusters=4,
#       threshold=0.5)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 2
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_003["kmodes"], results_003["kmodes"] = try_model("kmodes")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0     -0.3124              1.154  ...           0             0
#
# [1 rows x 6 columns]
# KModes(cat_dissim=<function matching_dissim at 0x7fce8525b0e0>, init='Cao',
#        max_iter=100, n_clusters=4, n_init=1, n_jobs=-1, random_state=123,
#        verbose=0)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 1
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %% [markdown]
# ## Evaluate Results by Eye Color Labels

# %%
from sklearn.metrics import (
    silhouette_score, calinski_harabasz_score, davies_bouldin_score,
    homogeneity_score, adjusted_rand_score, completeness_score
)

# %%
assert (labels.index == dataset_outer_iris.index).sum() == dataset_outer_iris.shape[0]

# %%
color_map = {"BROWN": 0, "INTERMEDIATE": 1, "BLUE": 2}

# %%
def find_transformed_dataset(experiment):
    for item in experiment:
        if (
            isinstance(item, list) 
            and len(item) > 1 
            and isinstance(item[1], tuple) 
            and len(item[1]) > 1 
            and item[1][0] == 'Transformed Data'
            and isinstance(item[1][1], pd.DataFrame) 
        ):
            return item[1][1]

# %%
exp_003_dataset = find_transformed_dataset(exp_003)
X = exp_003_dataset.values
y = labels['Colore_IRISPLEX'].apply(lambda x: color_map[x])

# %%
dataset_outer_iris.shape
# Out:
# (238, 4)

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, y),
            "calinski_harabasz": calinski_harabasz_score(X, y),
            "davies_bouldin": davies_bouldin_score(X, y),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.244573         112.552727        1.293065

# %% [markdown]
# ## Kmedoids Clustering with Custom Distance Metric
#
# Here we use additional clustering method: `KMedoids` which supports custom distance metric. We will apply clustering for euclidean distance metric and cielab color distance metric which we will define bellow.

# %%
from sklearn_extra.cluster import KMedoids
import colormath as cmth
from colormath.color_diff import delta_e_cie2000
from colormath.color_objects import sRGBColor,LabColor
from sklearn.metrics import pairwise_distances
import colormath.color_diff as cldf

# %%
def cie2000_distance(p1, p2):
    return cldf.delta_e_cie2000(
        color1=LabColor(*p1),
        color2=LabColor(*p2),
    )

def euclidean_distance(p1, p2):
    diff = p1 - p2
    return np.vdot(diff, diff) ** 0.5

# %% [markdown]
# We set `n_clusters=4` bellow because that number was consistent across three best model results tried out above!!!

# %%
kmedoids_euclidean_003 = KMedoids(
    n_clusters=4,
    metric=euclidean_distance,
    method='alternate',
    init='heuristic',
    max_iter=300,
    random_state=0,
).fit(X)

# %%
kmedoids_cielab_003 = KMedoids(
    n_clusters=4,
    metric=cie2000_distance,
    method='alternate',
    init='heuristic',
    max_iter=300,
    random_state=0,
).fit(X)

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, kmedoids_euclidean_003.labels_),
            "calinski_harabasz": calinski_harabasz_score(X, kmedoids_euclidean_003.labels_),
            "davies_bouldin": davies_bouldin_score(X, kmedoids_euclidean_003.labels_),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.309583         193.574715        1.086957

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, kmedoids_cielab_003.labels_),
            "calinski_harabasz": calinski_harabasz_score(X, kmedoids_cielab_003.labels_),
            "davies_bouldin": davies_bouldin_score(X, kmedoids_cielab_003.labels_),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.285652         178.279022        1.318061

# %% [markdown]
# <font color='red'>**As we see the CIE2000 distance metric is worsening clustering performance a little bit compared to traditional euclidean distance one!**</font>

# %% [markdown]
# ### Add KMedoid results

# %%
_sample_results = next(iter(results_003.items()))[1]

# %%
results_003['kmedoids_euclidean'] = _sample_results.iloc[:, :-1]
results_003['kmedoids_cielab'] = _sample_results.iloc[:, :-1]

# %%
results_003['kmedoids_euclidean']["Cluster"] = pd.Series(kmedoids_euclidean_003.labels_).apply(lambda x: f"Cluster {x}").tolist()
results_003['kmedoids_cielab']["Cluster"] = pd.Series(kmedoids_cielab_003.labels_).apply(lambda x: f"Cluster {x}").tolist()

# %% [markdown]
# # Check consistency between manual labels and clustering results

# %%
def consistency_check(clustering_result, labels):
    return pd.concat([clustering_result, labels], axis=1).groupby('Cluster').Colore_IRISPLEX.value_counts()

# %%
for model_name, model_results in results_003.items():
    print('='*50)
    print(f"MODEL: {model_name}")
    print(consistency_check(model_results, labels))
    print('+'*50)
    print(f'Adjusted Rand Index: {adjusted_rand_score(labels.Colore_IRISPLEX.values, model_results.Cluster.values)}')
    print('+'*50)
# Out:
# ==================================================
# MODEL: kmeans
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              61
#            INTERMEDIATE       29
# Cluster 1  BLUE               19
# Cluster 2  BROWN              90
#            INTERMEDIATE        3
# Cluster 3  INTERMEDIATE       23
#            BLUE               10
#            BROWN               3
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3315495669828409
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: ap
# Cluster     Colore_IRISPLEX
# Cluster 0   BLUE                8
# Cluster 1   BROWN              16
# Cluster 10  BROWN              23
# Cluster 11  BROWN              13
#             INTERMEDIATE        1
# Cluster 12  INTERMEDIATE       12
#             BROWN               2
# Cluster 13  BROWN              15
# Cluster 14  INTERMEDIATE       10
#             BROWN               9
# Cluster 15  BROWN              14
#             INTERMEDIATE        1
# Cluster 16  BROWN              12
#             INTERMEDIATE        1
# Cluster 2   BLUE               13
# Cluster 3   BROWN              19
#             INTERMEDIATE        1
# Cluster 4   INTERMEDIATE       10
#             BLUE                2
#             BROWN               1
# Cluster 5   BROWN              22
#             INTERMEDIATE        1
# Cluster 6   BROWN               7
#             INTERMEDIATE        2
#             BLUE                1
# Cluster 7   INTERMEDIATE        6
#             BLUE                1
# Cluster 8   BLUE                4
#             INTERMEDIATE        4
#             BROWN               1
# Cluster 9   INTERMEDIATE        6
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.09132932455566735
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: meanshift
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              153
#            INTERMEDIATE        36
#            BLUE                 2
# Cluster 1  BLUE                27
#            INTERMEDIATE        19
#            BROWN                1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.48546670527998115
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: sc
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              154
#            INTERMEDIATE        54
#            BLUE                25
# Cluster 1  INTERMEDIATE         1
# Cluster 2  BLUE                 3
# Cluster 3  BLUE                 1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.056728961420306076
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: hclust
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              65
#            INTERMEDIATE       32
#            BLUE                1
# Cluster 1  INTERMEDIATE       22
#            BROWN              14
#            BLUE               10
# Cluster 2  BROWN              75
#            INTERMEDIATE        1
# Cluster 3  BLUE               18
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.23090465442354374
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: dbscan
# Cluster     Colore_IRISPLEX
# Cluster -1  BROWN              154
#             INTERMEDIATE        55
#             BLUE                29
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.0
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: optics
# Cluster     Colore_IRISPLEX
# Cluster -1  BROWN              96
#             INTERMEDIATE       43
#             BLUE               15
# Cluster 0   BROWN               4
#             INTERMEDIATE        1
# Cluster 1   BROWN               5
# Cluster 10  BLUE               14
# Cluster 2   BROWN               7
# Cluster 3   BROWN               7
# Cluster 4   BROWN               9
# Cluster 5   BROWN               6
# Cluster 6   BROWN               5
#             INTERMEDIATE        2
# Cluster 7   BROWN               5
#             INTERMEDIATE        2
# Cluster 8   INTERMEDIATE        7
# Cluster 9   BROWN              10
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: -0.000902713847142697
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: birch
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              66
#            INTERMEDIATE       34
#            BLUE                1
# Cluster 1  INTERMEDIATE       18
#            BLUE               10
# Cluster 2  BROWN              88
#            INTERMEDIATE        3
# Cluster 3  BLUE               18
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3146560258093932
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmodes
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              152
#            INTERMEDIATE        54
#            BLUE                29
# Cluster 1  BROWN                1
# Cluster 2  INTERMEDIATE         1
# Cluster 3  BROWN                1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: -0.0021754180603685462
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmedoids_euclidean
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              33
#            INTERMEDIATE       23
# Cluster 1  BROWN              46
#            INTERMEDIATE       12
#            BLUE                2
# Cluster 2  BLUE               27
#            INTERMEDIATE       19
#            BROWN               1
# Cluster 3  BROWN              74
#            INTERMEDIATE        1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.2350035345515464
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmedoids_cielab
# Cluster    Colore_IRISPLEX
# Cluster 0  INTERMEDIATE       33
#            BROWN              26
#            BLUE                1
# Cluster 1  BROWN              80
#            INTERMEDIATE        1
# Cluster 2  BROWN              47
#            INTERMEDIATE        3
# Cluster 3  BLUE               28
#            INTERMEDIATE       18
#            BROWN               1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.29959555048887165
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Check Clusterings visually

# %%
for model_name, model_results in results_003.items():
    print('='*50)
    print(f"MODEL: {model_name}\tN_Clusters: {model_results.Cluster.unique().shape[0]}")
    pio.write_html(
        fig=show_lab_scatter_3d_shapes(model_results, labels),
        file=FIGURES_DIR + f"outer_eye_original_{model_name}_{model_results.Cluster.unique().shape[0]}_clusters.html"
    )
    print('='*50)
# Out:
# ==================================================
# MODEL: kmeans	N_Clusters: 4
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="327430e9-da3f-4440-8731-301d9f6fed93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327430e9-da3f-4440-8731-301d9f6fed93")) {                    Plotly.newPlot(                        "327430e9-da3f-4440-8731-301d9f6fed93",                        [{"marker": {"color": ["#332a18", "#42341d", "#666b5a", "#706141", "#497690", "#363335", "#4c4e35", "#587d87", "#536964", "#819587", "#62605b", "#4b6c6d", "#191d26", "#626b49", "#262426", "#503f2f", "#35647f", "#4a788f", "#31251e", "#171414", "#4f645a", "#302824", "#5a858e", "#4d443a", "#4b3f1f", "#4b463d", "#25211f", "#201f23", "#38443f", "#3d6379", "#3b3420", "#3b3432", "#5a645b", "#413834", "#3f3836", "#45717f", "#4b452b", "#39302c", "#404431", "#4f3f35", "#372b1c", "#676248", "#3e3c38", "#5e5134", "#544430", "#4c413d", "#30241e", "#3d3530", "#2c2c2e", "#4d3c2a", "#5a797d", "#2c2422", "#594b3c", "#413731", "#3e2f29", "#272c34", "#465a59", "#474a35", "#5e5444", "#4d382e", "#627174", "#302620", "#554a3d", "#393934", "#3d3736", "#30251d", "#444a45", "#2b2e38", "#312c2b", "#454c3b", "#373324", "#575958", "#3c6373", "#595545", "#51452a", "#2b271d", "#3f3126", "#39322f", "#343221", "#6a7d6f", "#404e4e", "#1f1f23", "#221c1b", "#654c23", "#3c332d", "#67553b", "#2f2b2a", "#5c6154", "#372d28", "#372d2a", "#524235", "#443b33", "#707057", "#60634a", "#513d31", "#322722", "#59584a", "#5b5447", "#454f40", "#40322d", "#3f3939", "#4d3c2f", "#63573a", "#3e514b", "#483929", "#58452f", "#4e7585", "#4a8099", "#4e3d2a", "#3f3d2e", "#2e2b2c", "#5b4a40", "#332e31", "#322b2c", "#5e524f", "#4e5952", "#6a7c69", "#4b4028", "#282527", "#2d2627", "#685638", "#464034", "#5b6e70", "#352619", "#564b47", "#5b8594", "#65513c", "#6c5b37", "#3a3c46", "#2e2623", "#39373d", "#393436", "#5a4934", "#3b2f28", "#595047", "#40352a
# ==================================================

# %% [markdown]
# ## Store Clustering Results as a JSON

# %%
for model_name, model_results in results_003.items():
    _clustering_results = pd.merge(results_003[model_name][['Cluster']], labels, left_index=True, right_index=True)
    _clustering_results.to_json(CLUSTERS_DIR + f"outer_eye_original_{model_name}_{model_results.Cluster.unique().shape[0]}_clusters.json")

# %% [markdown]
# ## Store Clustering Dataset

# %%
exp_003_dataset.to_csv(DATASETS_DIR + f"outer_eye_original_dataset.csv")

# %% [markdown]
# ## Store Clustering Metrics Results for each model

# %%
def get_metrics(experiment):
  for item in experiment:
    if (
        isinstance(item, list)
        and len(item) > 1
        and isinstance(item[1], pd.DataFrame)
        and "".join(item[0].columns) == "DescriptionValue"
        and "".join(item[1].columns) == "SilhouetteCalinski-HarabaszDavies-BouldinHomogeneityRand IndexCompleteness"
    ):
      only_metrics = pd.concat(item[1:]).reset_index(drop=True)
      model_metrics = pd.concat([only_metrics, pd.DataFrame({"model":MODEL_NAMES})],axis=1)

      return model_metrics

# %%
exp_003_metrics = get_metrics(exp_003)
exp_003_metrics
# Out:
#    Silhouette  Calinski-Harabasz  ...  Completeness      model
# 0      0.4066           226.4846  ...             0     kmeans
# 1      0.3090           173.6177  ...             0         ap
# 2      0.4891           193.0746  ...             0  meanshift
# 3      0.3044             7.0123  ...             0         sc
# 4      0.3511           186.9224  ...             0     hclust
# 5      0.0000             0.0000  ...             0     dbscan
# 6     -0.2278            13.0414  ...             0     optics
# 7      0.3890           204.0435  ...             0      birch
# 8     -0.3124             1.1540  ...             0     kmodes
#
# [9 rows x 7 columns]

# %%
exp_003_metrics.to_csv(METRICS_DIR + f"outer_eye_original_model_metrics.csv")

# %% [markdown]
# # Clustering (outer iris normalized)

# %% [markdown]
# Run pycaret experiments using different models and on 2 different datasets that we got here

# %%
from pycaret.clustering import *

# %%
exp_004 = setup(
    data=dataset_outer_iris,
    preprocess=True,
    ignore_features=['hex_color'],
    
    # normalize
    normalize=True,
    normalize_method='minmax',
    
    # transform
    transformation=False,
    transformation_method='yeo-johnson',
    
    # pca
    pca=False,
    pca_method='linear',
    
    
    silent=True,
    n_jobs=-1,
    
    # set experiment seed
    session_id=123
)
# Out:
#                                Description                 Value
# 0                               session_id                   123
# 1                            Original Data              (238, 4)
# 2                           Missing Values                 False
# 3                         Numeric Features                     3
# 4                     Categorical Features                     0
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data              (238, 3)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  cluster-default-name
# 13                                     USI                  a79f
# 14                         Imputation Type                simple
# 15          Iterative Imputation Iteration                  None
# 16                         Numeric Imputer                  mean
# 17      Iterative Imputation Numeric Model                  None
# 18                     Categorical Imputer                  mode
# 19  Iterative Imputation Categorical Model                  None
# 20           Unknown Categoricals Handling        least_frequent
# 21                               Normalize                  True
# 22                        Normalize Method                minmax
# 23                          Transformation                 False
# 24                   Transformation Method                  None
# 25                                     PCA                 False
# 26                              PCA Method                  None
# 27                          PCA Components                  None
# 28                     Ignore Low Variance                 False
# 29                     Combine Rare Levels                 False
# 30                    Rare Level Threshold                  None
# 31                         Numeric Binning                 False
# 32                         Remove Outliers                 False
# 33                      Outliers Threshold                  None
# 34                Remove Multicollinearity                 False
# 35             Multicollinearity Threshold                  None
# 36             Remove Perfect Collinearity                 False
# 37                              Clustering                 False
# 38                    Clustering Iteration                  None
# 39                     Polynomial Features                 False
# 40                       Polynomial Degree                  None
# 41                    Trignometry Features                 False
# 42                    Polynomial Threshold                  None
# 43                          Group Features                 False
# 44                       Feature Selection                 False
# 45                Feature Selection Method               classic
# 46            Features Selection Threshold                  None
# 47                     Feature Interaction                 False
# 48                           Feature Ratio                 False
# 49                   Interaction Threshold                  None

# %% [markdown]
# show all outputs from cell

# %%
def try_model(model_name, **kwargs):
    # create model
    model = create_model(model_name, **kwargs)
    # show model object
    print(model)
    # store model results
    results = assign_model(model)
    print(results.head(2))
    # evaluate model with interactive plot
    evaluate_model(model)
    
    return model, results

# %%
models_004 = {}
results_004 = {}

MODEL_NAMES = ["kmeans", "ap", "meanshift", "sc", "hclust", "dbscan", "optics", "birch", "kmodes"]

# %%
models_004["kmeans"], results_004["kmeans"] = try_model("kmeans", **{"num_clusters":3})
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.3849           252.2206  ...           0             0
#
# [1 rows x 6 columns]
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=-1, precompute_distances='deprecated',
#        random_state=123, tol=0.0001, verbose=0)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 2
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["ap"], results_004["ap"] = try_model("ap")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.2952            160.465  ...           0             0
#
# [1 rows x 6 columns]
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#                     damping=0.5, max_iter=200, preference=None,
#                     random_state='warn', verbose=False)
#                 l         a          b hex_color     Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 13
# FDP002  22.662753  2.493072  17.055058   #42341d   Cluster 5
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["meanshift"], results_004["meanshift"] = try_model("meanshift")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.5277           268.4269  ...           0             0
#
# [1 rows x 6 columns]
# MeanShift(bandwidth=None, bin_seeding=False, cluster_all=True, max_iter=300,
#           min_bin_freq=1, n_jobs=-1, seeds=None)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["sc"], results_004["sc"] = try_model("sc", **{"num_clusters": 3})
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0       0.371           232.5254  ...           0             0
#
# [1 rows x 6 columns]
# SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3,
#                    eigen_solver=None, eigen_tol=0.0, gamma=1.0,
#                    kernel_params=None, n_clusters=3, n_components=None,
#                    n_init=10, n_jobs=-1, n_neighbors=10, random_state=123)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 1
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 2
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["hclust"], results_004["hclust"] = try_model("hclust")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      0.3493           213.5912  ...           0             0
#
# [1 rows x 6 columns]
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=4)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 2
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["dbscan"], results_004["dbscan"] = try_model("dbscan")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0           0                  0  ...           0             0
#
# [1 rows x 6 columns]
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=-1, p=None)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["optics"], results_004["optics"] = try_model("optics")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0      -0.256            13.8155  ...           0             0
#
# [1 rows x 6 columns]
# OPTICS(algorithm='auto', cluster_method='xi', eps=None, leaf_size=30,
#        max_eps=inf, metric='minkowski', metric_params=None,
#        min_cluster_size=None, min_samples=5, n_jobs=-1, p=2,
#        predecessor_correction=True, xi=0.05)
#                 l         a          b hex_color     Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster -1
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster -1
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["birch"], results_004["birch"] = try_model("birch")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0           0                  0  ...           0             0
#
# [1 rows x 6 columns]
# Birch(branching_factor=50, compute_labels=True, copy=True, n_clusters=4,
#       threshold=0.5)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 0
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %%
models_004["kmodes"], results_004["kmodes"] = try_model("kmodes")
# Out:
#    Silhouette  Calinski-Harabasz  ...  Rand Index  Completeness
# 0     -0.3688             0.9472  ...           0             0
#
# [1 rows x 6 columns]
# KModes(cat_dissim=<function matching_dissim at 0x7fce8525b0e0>, init='Cao',
#        max_iter=100, n_clusters=4, n_init=1, n_jobs=-1, random_state=123,
#        verbose=0)
#                 l         a          b hex_color    Cluster
# ID
# FDP001  17.671129  1.004831  13.675901   #332a18  Cluster 0
# FDP002  22.662753  2.493072  17.055058   #42341d  Cluster 1
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …

# %% [markdown]
# ## Evaluate Results by Eye Color Labels

# %%
from sklearn.metrics import (
    silhouette_score, calinski_harabasz_score, davies_bouldin_score,
    homogeneity_score, adjusted_rand_score, completeness_score
)

# %%
assert (labels.index == dataset_outer_iris.index).sum() == dataset_outer_iris.shape[0]

# %%
color_map = {"BROWN": 0, "INTERMEDIATE": 1, "BLUE": 2}

# %%
def find_transformed_dataset(experiment):
    for item in experiment:
        if (
            isinstance(item, list) 
            and len(item) > 1 
            and isinstance(item[1], tuple) 
            and len(item[1]) > 1 
            and item[1][0] == 'Transformed Data'
            and isinstance(item[1][1], pd.DataFrame) 
        ):
            return item[1][1]

# %%
exp_004_dataset = find_transformed_dataset(exp_004)
X = exp_004_dataset.values
y = labels['Colore_IRISPLEX'].apply(lambda x: color_map[x])

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, y),
            "calinski_harabasz": calinski_harabasz_score(X, y),
            "davies_bouldin": davies_bouldin_score(X, y),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.315665         153.535066        1.107469

# %% [markdown]
# ## Kmedoids Clustering with Custom Distance Metric
#
# Here we use additional clustering method: `KMedoids` which supports custom distance metric. We will apply clustering for euclidean distance metric and cielab color distance metric which we will define bellow.

# %%
from sklearn_extra.cluster import KMedoids
import colormath as cmth
from colormath.color_diff import delta_e_cie2000
from colormath.color_objects import sRGBColor,LabColor
from sklearn.metrics import pairwise_distances
import colormath.color_diff as cldf

# %%
def cie2000_distance(p1, p2):
    return cldf.delta_e_cie2000(
        color1=LabColor(*p1),
        color2=LabColor(*p2),
    )

def euclidean_distance(p1, p2):
    diff = p1 - p2
    return np.vdot(diff, diff) ** 0.5

# %% [markdown]
# We set `n_clusters=4` bellow because that number was consistent across three best model results tried out above!!!

# %%
kmedoids_euclidean_004 = KMedoids(
    n_clusters=4,
    metric=euclidean_distance,
    method='alternate',
    init='heuristic',
    max_iter=300,
    random_state=0,
).fit(X)

# %% [markdown]
# **we use previous kmedoids results (kmedoids_cielab_004 = kmedoids_cielab_003) since cie2000 distance works with original L,A,B values, but we measure clustering metrics on transformed dataset in LAB space**

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, kmedoids_euclidean_004.labels_),
            "calinski_harabasz": calinski_harabasz_score(X, kmedoids_euclidean_004.labels_),
            "davies_bouldin": davies_bouldin_score(X, kmedoids_euclidean_004.labels_),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.341955         217.772654        1.028019

# %%
pd.DataFrame(
    [
        {
            "silhouette": silhouette_score(X, kmedoids_cielab_003.labels_),
            "calinski_harabasz": calinski_harabasz_score(X, kmedoids_cielab_003.labels_),
            "davies_bouldin": davies_bouldin_score(X, kmedoids_cielab_003.labels_),
        }
    ]
)
# Out:
#    silhouette  calinski_harabasz  davies_bouldin
# 0    0.329934          213.03161        1.020328

# %% [markdown]
# <font color='red'>**As we see the CIE2000 distance metric is worsening clustering performance a little bit compared to traditional euclidean distance one!**</font>

# %% [markdown]
# ### Add KMedoid results

# %%
_sample_results = next(iter(results_004.items()))[1]

# %%
results_004['kmedoids_euclidean'] = _sample_results.iloc[:, :-1]
results_004['kmedoids_cielab'] = _sample_results.iloc[:, :-1]

# %%
results_004['kmedoids_euclidean']["Cluster"] = pd.Series(kmedoids_euclidean_004.labels_).apply(lambda x: f"Cluster {x}").tolist()
results_004['kmedoids_cielab']["Cluster"] = pd.Series(kmedoids_cielab_003.labels_).apply(lambda x: f"Cluster {x}").tolist()

# %% [markdown]
# # Check consistency between manual labels and clustering results

# %%
def consistency_check(clustering_result, labels):
    return pd.concat([clustering_result, labels], axis=1).groupby('Cluster').Colore_IRISPLEX.value_counts()

# %%
for model_name, model_results in results_004.items():
    print('='*50)
    print(f"MODEL: {model_name}")
    print(consistency_check(model_results, labels))
    print('+'*50)
    print(f'Adjusted Rand Index: {adjusted_rand_score(labels.Colore_IRISPLEX.values, model_results.Cluster.values)}')
    print('+'*50)
# Out:
# ==================================================
# MODEL: kmeans
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              62
#            INTERMEDIATE       32
# Cluster 1  BLUE               29
#            INTERMEDIATE       22
# Cluster 2  BROWN              92
#            INTERMEDIATE        1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3433642853269452
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: ap
# Cluster     Colore_IRISPLEX
# Cluster 0   BROWN              23
#             INTERMEDIATE        1
# Cluster 1   BLUE                6
# Cluster 10  BROWN              18
# Cluster 11  INTERMEDIATE        7
#             BLUE                1
# Cluster 12  BROWN              11
#             INTERMEDIATE        6
# Cluster 13  INTERMEDIATE       15
#             BROWN               5
# Cluster 14  BROWN               9
# Cluster 2   BROWN              23
# Cluster 3   BLUE                7
#             INTERMEDIATE        5
# Cluster 4   INTERMEDIATE        5
#             BLUE                1
# Cluster 5   BROWN              16
#             INTERMEDIATE        4
# Cluster 6   BROWN              13
# Cluster 7   BROWN              36
# Cluster 8   BLUE               13
# Cluster 9   INTERMEDIATE       12
#             BLUE                1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.12487026519945747
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: meanshift
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              154
#            INTERMEDIATE        31
# Cluster 1  BLUE                29
#            INTERMEDIATE        24
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.5633893997432924
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: sc
# Cluster    Colore_IRISPLEX
# Cluster 0  BLUE               28
#            INTERMEDIATE       12
# Cluster 1  BROWN              91
#            INTERMEDIATE        4
# Cluster 2  BROWN              63
#            INTERMEDIATE       39
#            BLUE                1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3073058677157343
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: hclust
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              69
#            INTERMEDIATE       31
#            BLUE                1
# Cluster 1  INTERMEDIATE       24
#            BLUE                8
# Cluster 2  BROWN              85
# Cluster 3  BLUE               20
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3387524792276906
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: dbscan
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              154
#            INTERMEDIATE        55
#            BLUE                29
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.0
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: optics
# Cluster     Colore_IRISPLEX
# Cluster -1  BROWN              107
#             INTERMEDIATE        42
#             BLUE                19
# Cluster 0   BROWN               11
# Cluster 1   BROWN                5
# Cluster 2   BROWN               10
# Cluster 3   BROWN                9
# Cluster 4   BROWN                4
#             INTERMEDIATE         1
# Cluster 5   BROWN                8
# Cluster 6   INTERMEDIATE         7
# Cluster 7   BLUE                10
# Cluster 8   INTERMEDIATE         5
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.0046203684342948845
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: birch
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              154
#            INTERMEDIATE        55
#            BLUE                29
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.0
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmodes
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              152
#            INTERMEDIATE        54
#            BLUE                29
# Cluster 1  BROWN                1
# Cluster 2  INTERMEDIATE         1
# Cluster 3  BROWN                1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: -0.0021754180603685462
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmedoids_euclidean
# Cluster    Colore_IRISPLEX
# Cluster 0  BROWN              80
#            INTERMEDIATE        1
# Cluster 1  INTERMEDIATE       32
#            BROWN              26
# Cluster 2  BLUE               29
#            INTERMEDIATE       19
# Cluster 3  BROWN              48
#            INTERMEDIATE        3
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.3097849204208007
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ==================================================
# MODEL: kmedoids_cielab
# Cluster    Colore_IRISPLEX
# Cluster 0  INTERMEDIATE       33
#            BROWN              26
#            BLUE                1
# Cluster 1  BROWN              80
#            INTERMEDIATE        1
# Cluster 2  BROWN              47
#            INTERMEDIATE        3
# Cluster 3  BLUE               28
#            INTERMEDIATE       18
#            BROWN               1
# Name: Colore_IRISPLEX, dtype: int64
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Adjusted Rand Index: 0.29959555048887165
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Check Clusterings visually

# %%
for model_name, model_results in results_004.items():
    print('='*50)
    print(f"MODEL: {model_name}\tN_Clusters: {model_results.Cluster.unique().shape[0]}")
    pio.write_html(
        fig=show_lab_scatter_3d_shapes(model_results, labels),
        file=FIGURES_DIR + f"outer_eye_normalized_{model_name}_{model_results.Cluster.unique().shape[0]}_clusters.html"
    )
    print('='*50)
# Out:
# ==================================================
# MODEL: kmeans	N_Clusters: 3
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="a7cddf68-5f2c-45ae-ad77-1e95841b42b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
#2d6a91", "#373133", "#382c27", "#4e462e", "#79643f", "#5d4833", "#38343a", "#334c50", "#312829", "#4f3d2b", "#37302f", "#4c3d25", "#261b10", "#55442b", "#4d4629", "#626342", "#534e44", "#191817", "#53463f", "#453a24", "#372a24", "#403226", "#554440", "#39322d", "#675a34", "#3e341b", "#59482e", "#342921", "#453e28", "#2a2322", "#393022", "#463d22", "#5c4627", "#6b796d", "#504527", "#524623", "#473928", "#412f28", "#342820", "#443936", "#4a3d39", "#524326", "#637973", "#477987", "#60563b", "#4c4138", "#3f332f", "#56412c", "#4e413e", "#47341d", "#28211e", "#645635", "#5d5242", "#3c3231", "#2e251d", "#575033", "#52361f", "#5e3d2a"], "size": 7, "symbol": ["circle", "diamond", "cross", "square", "cross", "circle", "square", "cross", "cross", "cross", "cross", "cross", "circle", "square", "circle", "diamond", "cross", "cross", "circle", "circle", "cross", "circle", "cross", "square", "square", "square", "circle", "circle", "square", "cross", "square", "circle", "cross", "circle", "circle", "cross", "square", "circle", "square", "diamond", "circle", "square", "circle", "square", "diamond", "diamond", "circle", "circle", "circle", "diamond", "cross", "circle", "diamond", "circle", "circle", "circle", "cross", "square", "square", "diamond", "cross", "circle", "square", "circle", "circle", "circle", "square", "circle", "circle", "square", "square", "cross", "cross", "square", "square", "circle", "diamond", "circle", "square", "cross",  ...
# ==================================================

# %% [markdown]
# ## Store Clustering Results as a JSON

# %%
for model_name, model_results in results_004.items():
    _clustering_results = pd.merge(results_004[model_name][['Cluster']], labels, left_index=True, right_index=True)
    _clustering_results.to_json(CLUSTERS_DIR + f"outer_eye_normalized_{model_name}_{model_results.Cluster.unique().shape[0]}_clusters.json")

# %% [markdown]
# ## Store Clustering Dataset

# %%
exp_004_dataset.to_csv(DATASETS_DIR + f"outer_eye_normalized_dataset.csv")

# %% [markdown]
# ## Store Clustering Metrics Results for each model

# %%
def get_metrics(experiment):
  for item in experiment:
    if (
        isinstance(item, list)
        and len(item) > 1
        and isinstance(item[1], pd.DataFrame)
        and "".join(item[0].columns) == "DescriptionValue"
        and "".join(item[1].columns) == "SilhouetteCalinski-HarabaszDavies-BouldinHomogeneityRand IndexCompleteness"
    ):
      only_metrics = pd.concat(item[1:]).reset_index(drop=True)
      model_metrics = pd.concat([only_metrics, pd.DataFrame({"model":MODEL_NAMES})],axis=1)

      return model_metrics

# %%
exp_004_metrics = get_metrics(exp_004)
exp_004_metrics
# Out:
#    Silhouette  Calinski-Harabasz  ...  Completeness      model
# 0      0.3849           252.2206  ...             0     kmeans
# 1      0.2952           160.4650  ...             0         ap
# 2      0.5277           268.4269  ...             0  meanshift
# 3      0.3710           232.5254  ...             0         sc
# 4      0.3493           213.5912  ...             0     hclust
# 5      0.0000             0.0000  ...             0     dbscan
# 6     -0.2560            13.8155  ...             0     optics
# 7      0.0000             0.0000  ...             0      birch
# 8     -0.3688             0.9472  ...             0     kmodes
#
# [9 rows x 7 columns]

# %%
exp_004_metrics.to_csv(METRICS_DIR + f"outer_eye_normalized_model_metrics.csv")
